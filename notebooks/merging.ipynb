# %%
import pandas as pd

# For Alabama temperature data
al_temp = pd.read_csv('../datasets/state_temperature_data/ohio_cleaned_temperature_data.csv')
print("\nAlabama Temperature Data Types:")
print(al_temp.dtypes)
print("\nFirst few rows of Alabama Temperature:")
print(al_temp.head())

# For electricity usage data
elec_usage = pd.read_csv('../datasets/cleaned_electricity_usage_data.csv')
print("\nElectricity Usage Data Types:")
print(elec_usage.dtypes)
print("\nFirst few rows of Alabama Electricity Usage:")
print(elec_usage[elec_usage['stateDescription'] == 'Alabama'].head())
# Out:
# Alabama Temperature Data Types:
# year       int64
# month      int64
# tavg     float64
# dtype: object
#
# First few rows of Alabama Temperature:
#    year  month  tavg
# 0  2001      1  28.0
# 1  2001      2  32.0
# 2  2001      3  42.0
# 3  2001      4  52.0
# 4  2001      5  62.5
#
# Electricity Usage Data Types:
# year                  int64
# month                 int64
# stateDescription     object
# sectorName           object
# price               float64
# revenue             float64
# sales               float64
# dtype: object
#
# First few rows of Alabama Electricity Usage:
#      year  month stateDescription   sectorName  price    revenue       sales
# 10   2001      1          Alabama  all sectors   5.54  407.61261  7362.47302
# 53   2001      2          Alabama  all sectors   5.31  321.06715  6041.02574
# 110  2001      3          Alabama  all sectors   5.87  345.77802  5894.61038
# 173  2001      4          Alabama  all sectors   5.72  347.18634  6064.53539
# 248  2001      5          Alabama  all sectors   5.60  359.09236  6413.96530

# %%
# First load both datasets
elec_df = pd.read_csv('../datasets/cleaned_electricity_usage_data.csv')
al_temp = pd.read_csv('../datasets/state_temperature_data/alabama_cleaned_temperature_data.csv')

# Since we want to merge with state name, let's add state column to temperature data
al_temp['stateDescription'] = 'Alabama'

# Merge datasets for Alabama only
# This keeps all electricity columns and adds temperature at the end
test_merge = pd.merge(
    elec_df[elec_df['stateDescription'] == 'Alabama'],
    al_temp[['year', 'month', 'stateDescription', 'tavg']],
    on=['year', 'month', 'stateDescription'],
    how='left'
)

# Rename the temperature column
test_merge = test_merge.rename(columns={'tavg': 'average temperature in Fahrenheit'})

test_merge.to_csv('../datasets/test.csv', index=False)

# %%
import pandas as pd
import glob
import os

# 1. Read the main electricity usage data
elec_df = pd.read_csv('../datasets/cleaned_electricity_usage_data.csv')

# 2. Get list of all state temperature files
state_files = glob.glob('../datasets/state_temperature_data/*_cleaned_temperature_data.csv')

# Print to check if we're finding the files
print(f"Found {len(state_files)} state files:")
print(state_files[:5])  # Print first 5 files to verify

# 3. Create empty list to store merged data for each state
merged_states = []

# 4. Loop through each state file
for state_file in state_files:
    # Extract state name from file name
    # Handle compound state names properly
    state_file_name = os.path.basename(state_file)
    state_name = state_file_name.split('_cleaned_temperature_data.csv')[0].replace('_', ' ').title()
    print(f"\nProcessing state: {state_name}")
    
    # Read state's temperature data
    state_temp = pd.read_csv(state_file)
    print(f"Temperature data shape: {state_temp.shape}")
    
    # Print to verify we have matching records in electricity data
    state_elec = elec_df[elec_df['stateDescription'] == state_name]
    print(f"Electricity data shape for {state_name}: {state_elec.shape}")
    
    # Add state name to temperature data
    state_temp['stateDescription'] = state_name
    
    # Merge this state's data
    state_merged = pd.merge(
        state_elec,
        state_temp[['year', 'month', 'stateDescription', 'tavg']],
        on=['year', 'month', 'stateDescription'],
        how='left'
    )
    print(f"Merged shape: {state_merged.shape}")
    
    # Add to our list of merged states
    merged_states.append(state_merged)

print(f"\nTotal states processed: {len(merged_states)}")
# Out:
# Found 50 state files:
# ['../datasets/state_temperature_data\\alabama_cleaned_temperature_data.csv', '../datasets/state_temperature_data\\alaska_cleaned_temperature_data.csv', '../datasets/state_temperature_data\\arizona_cleaned_temperature_data.csv', '../datasets/state_temperature_data\\arkansas_cleaned_temperature_data.csv', '../datasets/state_temperature_data\\california_cleaned_temperature_data.csv']
#
# Processing state: Alabama
# Temperature data shape: (287, 3)
# Electricity data shape for Alabama: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Alaska
# Temperature data shape: (287, 3)
# Electricity data shape for Alaska: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Arizona
# Temperature data shape: (287, 3)
# Electricity data shape for Arizona: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Arkansas
# Temperature data shape: (287, 3)
# Electricity data shape for Arkansas: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: California
# Temperature data shape: (286, 3)
# Electricity data shape for California: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Colorado
# Temperature data shape: (287, 3)
# Electricity data shape for Colorado: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Connecticut
# Temperature data shape: (286, 3)
# Electricity data shape for Connecticut: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Delaware
# Temperature data shape: (287, 3)
# Electricity data shape for Delaware: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Florida
# Temperature data shape: (287, 3)
# Electricity data shape for Florida: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Georgia
# Temperature data shape: (287, 3)
# Electricity data shape for Georgia: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Hawaii
# Temperature data shape: (287, 3)
# Electricity data shape for Hawaii: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Idaho
# Temperature data shape: (287, 3)
# Electricity data shape for Idaho: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Illinois
# Temperature data shape: (286, 3)
# Electricity data shape for Illinois: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Indiana
# Temperature data shape: (287, 3)
# Electricity data shape for Indiana: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Iowa
# Temperature data shape: (287, 3)
# Electricity data shape for Iowa: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Kansas
# Temperature data shape: (287, 3)
# Electricity data shape for Kansas: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Kentucky
# Temperature data shape: (286, 3)
# Electricity data shape for Kentucky: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Louisiana
# Temperature data shape: (287, 3)
# Electricity data shape for Louisiana: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Maine
# Temperature data shape: (286, 3)
# Electricity data shape for Maine: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Maryland
# Temperature data shape: (287, 3)
# Electricity data shape for Maryland: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Massachusetts
# Temperature data shape: (287, 3)
# Electricity data shape for Massachusetts: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Michigan
# Temperature data shape: (286, 3)
# Electricity data shape for Michigan: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Minnesota
# Temperature data shape: (287, 3)
# Electricity data shape for Minnesota: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Mississippi
# Temperature data shape: (286, 3)
# Electricity data shape for Mississippi: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Missouri
# Temperature data shape: (286, 3)
# Electricity data shape for Missouri: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Montana
# Temperature data shape: (286, 3)
# Electricity data shape for Montana: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Nebraska
# Temperature data shape: (286, 3)
# Electricity data shape for Nebraska: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Nevada
# Temperature data shape: (287, 3)
# Electricity data shape for Nevada: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: New Hampshire
# Temperature data shape: (286, 3)
# Electricity data shape for New Hampshire: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: New Jersey
# Temperature data shape: (287, 3)
# Electricity data shape for New Jersey: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: New Mexico
# Temperature data shape: (287, 3)
# Electricity data shape for New Mexico: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: New York
# Temperature data shape: (287, 3)
# Electricity data shape for New York: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: North Carolina
# Temperature data shape: (287, 3)
# Electricity data shape for North Carolina: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: North Dakota
# Temperature data shape: (287, 3)
# Electricity data shape for North Dakota: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Ohio
# Temperature data shape: (287, 3)
# Electricity data shape for Ohio: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Oklahoma
# Temperature data shape: (287, 3)
# Electricity data shape for Oklahoma: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Oregon
# Temperature data shape: (286, 3)
# Electricity data shape for Oregon: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Pennsylvania
# Temperature data shape: (286, 3)
# Electricity data shape for Pennsylvania: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Rhode Island
# Temperature data shape: (286, 3)
# Electricity data shape for Rhode Island: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: South Carolina
# Temperature data shape: (286, 3)
# Electricity data shape for South Carolina: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: South Dakota
# Temperature data shape: (286, 3)
# Electricity data shape for South Dakota: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Tennessee
# Temperature data shape: (287, 3)
# Electricity data shape for Tennessee: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Texas
# Temperature data shape: (287, 3)
# Electricity data shape for Texas: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Utah
# Temperature data shape: (287, 3)
# Electricity data shape for Utah: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Vermont
# Temperature data shape: (286, 3)
# Electricity data shape for Vermont: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Virginia
# Temperature data shape: (287, 3)
# Electricity data shape for Virginia: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Washington
# Temperature data shape: (286, 3)
# Electricity data shape for Washington: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: West Virginia
# Temperature data shape: (286, 3)
# Electricity data shape for West Virginia: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Wisconsin
# Temperature data shape: (287, 3)
# Electricity data shape for Wisconsin: (277, 7)
# Merged shape: (277, 8)
#
# Processing state: Wyoming
# Temperature data shape: (287, 3)
# Electricity data shape for Wyoming: (277, 7)
# Merged shape: (277, 8)
#
# Total states processed: 50

# %%
# 5. Combine all states into one DataFrame
final_df = pd.concat(merged_states, ignore_index=True)

# 6. Sort the data by state, year, and month
final_df = final_df.sort_values(['stateDescription', 'year', 'month'])

# 7. Save to new CSV file
final_df.to_csv('../datasets/merged_electricity_temperature_data.csv', index=False)

# 8. Print some information about the final dataset
print("\nFinal merged dataset info:")
print(f"Total number of records: {len(final_df)}")
print(f"Number of states: {final_df['stateDescription'].nunique()}")
print(f"Date range: {final_df['year'].min()}-{final_df['month'].min()} to {final_df['year'].max()}-{final_df['month'].max()}")
print("\nFirst few rows:")
print(final_df.head())
# Out:
# Final merged dataset info:
# Total number of records: 13850
# Number of states: 50
# Date range: 2001-1 to 2024-12
#
# First few rows:
#    year  month stateDescription   sectorName  price    revenue       sales  \
# 0  2001      1          Alabama  all sectors   5.54  407.61261  7362.47302
# 1  2001      2          Alabama  all sectors   5.31  321.06715  6041.02574
# 2  2001      3          Alabama  all sectors   5.87  345.77802  5894.61038
# 3  2001      4          Alabama  all sectors   5.72  347.18634  6064.53539
# 4  2001      5          Alabama  all sectors   5.60  359.09236  6413.96530
#
#    tavg
# 0  43.7
# 1  55.0
# 2  53.4
# 3  66.0
# 4  72.2

# %%
load = pd.read_csv('../datasets/merged_electricity_temperature_data.csv')
load.shape
# Out:
# (13850, 8)
